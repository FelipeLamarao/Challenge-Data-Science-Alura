# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)


loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
loja['Loja'] = 'Loja'
loja2['Loja'] = 'Loja2'
loja3['Loja'] = 'Loja3'
loja4['Loja'] = 'Loja4'
loja2.head(15)
# Out:
#                   Produto   Categoria do Produto    Preço      Frete  \
# 0   Cadeira de escritório                 moveis   378.20  20.421138
# 1                Pandeiro  instrumentos musicais   102.37   3.035334
# 2               Cama king                 moveis   591.13  31.759020
# 3               Cama king                 moveis  1208.24  61.919584
# 4   Cadeira de escritório                 moveis   530.41  25.827176
# 5                  Violão  instrumentos musicais   397.84  21.466909
# 6                 Mochila        esporte e lazer   141.24  12.000644
# 7             Tablet ABXY            eletronicos  1283.53  65.928550
# 8       Panela de pressão  utilidades domesticas   110.40   6.409572
# 9         Cubo mágico 8x8             brinquedos    12.09   5.123795
# 10                Mochila        esporte e lazer   115.70  12.402612
# 11     Secadora de roupas       eletrodomesticos  1171.84  62.680081
# 12      Jogo de tabuleiro             brinquedos   203.95  11.799572
# ...

# %%
todas_lojas = pd.concat([loja, loja2,  loja3 , loja4], ignore_index=True)
todas_lojas['Faturamento'] = todas_lojas['Preço'] + todas_lojas['Frete']
todas_lojas.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon  Loja  Faturamento
# ...

# %%
todas_lojas.groupby('Loja')['Faturamento'].sum()
# Out:
# Loja
# Loja     1.616347e+06
# Loja2    1.567773e+06
# Loja3    1.542048e+06
# Loja4    1.458253e+06
# Name: Faturamento, dtype: float64

# %% [markdown]
# # 2. Vendas por Categoria

# %%
todas_lojas.groupby('Categoria do Produto')['Faturamento'].sum()
# Out:
# Categoria do Produto
# brinquedos               1.035024e+05
# eletrodomesticos         1.860199e+06
# eletronicos              2.332048e+06
# esporte e lazer          2.008919e+05
# instrumentos musicais    4.897015e+05
# livros                   5.300743e+04
# moveis                   1.064150e+06
# utilidades domesticas    8.092172e+04
# Name: Faturamento, dtype: float64

# %%
todas_lojas.groupby('Categoria do Produto')['Produto'].count()
# Out:
# Categoria do Produto
# brinquedos               1290
# eletrodomesticos         1149
# eletronicos              1772
# esporte e lazer          1113
# instrumentos musicais     753
# livros                    742
# moveis                   1886
# utilidades domesticas     730
# Name: Produto, dtype: int64

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
todas_lojas.groupby('Loja')['Avaliação da compra'].mean().round(2)
# Out:
# Loja
# Loja     3.98
# Loja2    4.04
# Loja3    4.05
# Loja4    4.00
# Name: Avaliação da compra, dtype: float64

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
todas_lojas['Produto'].value_counts()
# Out:
# Produto
# Cômoda                         210
# Carrinho controle remoto       206
# Micro-ondas                    206
# Bateria                        203
# Cama king                      201
# Secadora de roupas             200
# Modelagem preditiva            200
# Jogo de panelas                200
# Cama box                       199
# Blocos de montar               199
# Celular Plus X42               198
# Guarda roupas                  197
# Pandeiro                       197
# Bola de basquete               197
# Bicicleta                      196
# Iniciando em programação       195
# Smart TV                       192
# Geladeira                      191
# Lava louças                    189
# Faqueiro                       189
# Violão                         188
# Impressora                     188
# Kit banquetas                  188
# Copo térmico                   187
# Fogão                          187
# TV Led UHD 4K                  187
# ...

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
todas_lojas.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon  Loja  Faturamento
# ...

# %%
todas_lojas.groupby('Loja')['Frete'].mean().round(2)
# Out:
# Loja
# Loja     34.69
# Loja2    33.62
# Loja3    33.07
# Loja4    31.28
# Name: Frete, dtype: float64
